# %% [markdown]
# ## Vectorstores and Embeddings
#
# Recall the overall workflow for retrieval augmented generation (RAG):

# %% [markdown]
# <img src="fig3.jpg" width="600">

# %% [markdown]
# ### Vectorstores
# <img src="fig4.png" width="400">

# %% [markdown]
# ### Embeddings
#
# <img src="fig5.png" width="500">
#
# <img src="fig6.png" width="600">

# %% [markdown]
# ### Vector Store
#
# <img src="fig7.png" width="550">
#
# ### Vector Store/Database
#
# <img src="fig9.png" width="600">

# %%
import openai
import os
from dotenv import load_dotenv, find_dotenv
from getpass import getpass

# 사용할 API Key 이름
API_KEY_NAME = "OPENAI_API_KEY"

if find_dotenv():
    _ = load_dotenv(find_dotenv())
    openai.api_key = os.getenv(API_KEY_NAME)
else:
    openai.api_key = getpass(f"Enter {API_KEY_NAME}: ")
    os.environ[API_KEY_NAME] = openai.api_key

print(f"{API_KEY_NAME} loaded successfully.")
# Out:
# OPENAI_API_KEY loaded successfully.

# %% [markdown]
# We just discussed Document Loading and Splitting.

# %%
# !pip install -U langchain langchain-community langchain-core 
# !pip install -U langchain-text-splitters langchain-openai openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in c:\users\user\appdata\roaming\python\python312\site-packages (1.3.1)
# Requirement already satisfied: langchain-community in c:\users\user\appdata\roaming\python\python312\site-packages (0.4.2)
# Requirement already satisfied: langchain-core in c:\users\user\appdata\roaming\python\python312\site-packages (1.4.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain) (1.2.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-community) (0.8.5)
# Requirement already satisfied: numpy>=1.26.2 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (2.0.30)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-core) (0.0.15)
# Requirement already satisfied: packaging>=23.2.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core) (23.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-core) (0.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (0.3.15)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langgraph<1.3.0,>=1.2.0->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.27.2)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\user\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\user\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.2)
# Requirement already satisfied: certifi>=2023.5.7 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.2)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.0->langchain) (1.12.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-text-splitters in c:\users\user\appdata\roaming\python\python312\site-packages (1.1.2)
# Requirement already satisfied: langchain-openai in c:\users\user\appdata\roaming\python\python312\site-packages (1.2.2)
# Requirement already satisfied: openai in c:\users\user\appdata\roaming\python\python312\site-packages (2.38.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-text-splitters) (1.4.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\user\appdata\roaming\python\python312\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\user\appdata\roaming\python\python312\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\programdata\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (23.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (8.5.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\user\appdata\roaming\python\python312\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\programdata\anaconda3\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2023.10.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.34.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\user\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.2.2)

# %%
from langchain_community.document_loaders import PyPDFLoader

# Load PDF
loaders = [
    # Duplicate documents on purpose - messy data
    PyPDFLoader("docs/cs229_lectures/MachineLearning-Lecture01.pdf"),
    PyPDFLoader("docs/cs229_lectures/MachineLearning-Lecture01.pdf"),
    PyPDFLoader("docs/cs229_lectures/MachineLearning-Lecture02.pdf"),
    PyPDFLoader("docs/cs229_lectures/MachineLearning-Lecture03.pdf")
]
docs = []
for loader in loaders:
    docs.extend(loader.load())
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_30240\4035750999.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
# Split
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1500,
    chunk_overlap = 150
)

# %%
splits = text_splitter.split_documents(docs)

# %%
len(splits)
# Out:
# 208

# %% [markdown]
# ### Embeddings
# Let's take our splits and embed them.

# %%
from langchain_openai import OpenAIEmbeddings
embedding = OpenAIEmbeddings(model="text-embedding-3-small")

# %%
sentence1 = "i like dogs"
sentence2 = "i like canines"
sentence3 = "the weather is ugly outside"

# %%
embedding1 = embedding.embed_query(sentence1)
embedding2 = embedding.embed_query(sentence2)
embedding3 = embedding.embed_query(sentence3)

# %%
len(embedding1)
# Out:
# 1536

# %%
import numpy as np

# %%
np.dot(embedding1, embedding2)
# Out:
# 0.8339799163364319

# %%
np.dot(embedding1, embedding3)
# Out:
# 0.21910727885011738

# %%
np.dot(embedding2, embedding3)
# Out:
# 0.18508720851997396

# %% [markdown]
# ### Vectorstores

# %%
#!pip install -U langchain-chroma
from langchain_chroma  import Chroma

# %%
persist_directory = './docs/chroma'

# %%
vectordb = Chroma.from_documents(
    documents=splits,
    embedding=embedding,
    persist_directory=persist_directory
)

# %%
vectordb = Chroma.from_documents(documents=splits, embedding=embedding)

# %%
print(vectordb._collection.count())

# %% [markdown]
# ### Similarity Search

# %%
question = "is there an email i can ask for help"

# %%
docs = vectordb.similarity_search(question,k=3) # k is number of documents

# %%
len(docs)

# %%
docs[0].page_content

# %%
vectordb

# %% [markdown]
# ### Failure modes
#
# 이것은 훌륭해 보이며 기본 유사성 검색을 통해 80%의 결과를 매우 쉽게 얻을 수 있습니다.
#
# 그러나 서서히 나타날 수 있는 몇 가지 실패 모드가 있습니다.
#
# 다음은 발생할 수 있는 몇 가지 극단적인 경우입니다. 다음 수업에서 이를 수정하겠습니다.

# %%
question = "what did they say about matlab?"

# %%
docs = vectordb.similarity_search(question,k=5)

# %% [markdown]
# 중복 청크(인덱스에 MachineLearning-Lecture01.pdf가 중복되어 있기 때문에)가 표시됩니다.
#
# 시맨틱 검색은 모든 유사한 문서를 가져오지만 다양성을 강요하지는 않습니다.
#
# docs[0]과 docs[1]은 동일합니다.

# %%
docs[0]

# %%
docs[1]

# %% [markdown]
# 새로운 실패 모드를 볼 수 있습니다.
#
# 아래 질문은 세 번째 강의에 대한 질문이지만 다른 강의의 결과도 포함됩니다.

# %%
question = "what did they say about regression in the third lecture?"

# %%
docs = vectordb.similarity_search(question,k=5)

# %%
for doc in docs:
    print(doc.metadata)

# %%
print(docs[3].page_content)

# %% [markdown]
# 다음 강의에서 논의되는 접근 방식은 두 가지를 모두 해결하는 데 사용할 수 있습니다!
